# %% [markdown]
# Ripulisci il notebook:
# -ci sono analisi senza senso
# -rivedi la linea di regressione con sns e sklearn
# -guarda i video yt su microsoft developer sulla regressione

# %%
#importo le librerie necessarie per l'analisi
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import copy

import warnings
warnings.filterwarnings("ignore",category=FutureWarning)
warnings.filterwarnings("ignore",message="The figure layout has changed to tight")

# %%
#importo i file csv
df1 = pd.read_csv('/Users/francescomangini/Desktop/Python/Vs studio code/Notebook_/archive/googleplaystore.csv', decimal= '.')
df2 = pd.read_csv('/Users/francescomangini/Desktop/Python/Vs studio code/Notebook_/archive/googleplaystore_user_reviews.csv')

# %%
#visualizzo le prime 5 righe pel 1DF
df1.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#inizio l'esplorazione del primo dataset 
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#per il momento sappiamo che ci sono 10841 righe e 13 colonne
df1.shape
# Out:
# (10841, 13)

# %%
#Andiamo più a fondo, cerchiamo di capire quali sono le variabili delle colonne, le intestazioni di colonna e quanto è grande il DF
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Possiamo notare come in alcune colonne, il numero di Valori non-null sia più basso del numero totale di righe;
# Perciò possiamo dedurre che ci sono dei valori nulli, più avanti analizzeremo nel dettaglio questo punto.

# %%
df1.dtypes.value_counts()
#Possiamo dire con certezza che abbiamo 12 colonne con variabile "object" e 1 colonna con variabile "float64"
# Out:
# object     12
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# Adesso faccio una rapida esplorazione statistica del DF1
# (mi aspetto solo una colonna di risultato dato che ho solo una colonna con variabili numeriche)

# %%
df1.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# Notiamo un'anomalia:
# Vediamo come il Rating,solitamente sia in un intervallo che va da 0 a 5, in questo caso  abbiamo 19 che è letteralmente fuori intervallo.
#  Andiamo ad approfondire la questione

# %%
#cerchaimo i valori che hanno 'Rating' > 5
df1[df1['Rating'] > 5.0]
#vediamo che i valori sembrano scalati di un posto verso sx
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Controlliamo con le altre righe
df1.head(5)
#Effettivamente notiamo che i dati della riga 10472 sono scalati
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# Risolviamo questa anomalia scrivendo un piccolo codice.
# Divido la riga in due variabili,shifto il df wrong e riunisco i due df

# %%
good = df1[df1['Installs']=='Free'].iloc[:,0:1]
wrong = df1[df1['Installs']== 'Free'].iloc[:,1:13]

# %%
wrong = wrong.shift(periods=1,axis=1)
good = pd.concat([good,wrong],axis=1)

# %%
good
# Out:
#                                            App Category Rating  Reviews  Size  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame     None    1.9     19.0  3.0M
#
#       Installs  Type Price Content Rating Genres       Last Updated  \
# 10472   1,000+  Free     0       Everyone    NaN  February 11, 2018
#
#       Current Ver Android Ver
# 10472      1.0.19  4.0 and up

# %%
#Adesso uniamo i due DF per avere un solo DF
df1=pd.concat([df1,good],ignore_index=True) 
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                 None
#
# ...

# %%
#Adesso togliamo la riga con i valori sbagliati
df1=df1.drop(10472,axis=0)
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                 None
#
# ...

# %%
#Resettiamo il Datatype della colonna in dato numerico per farci le analisi statistiche
df1['Rating']= df1['Rating'].astype('Float64')

# %%
#adesso vediao che il valore massimo di 'Rating' è 5. Ha molto più senso come valore massimo di Rating
df1.describe()
# Out:
#          Rating
# count    9367.0
# mean   4.191513
# std    0.515735
# min         1.0
# 25%         4.0
# 50%         4.3
# 75%         4.5
# max         5.0

# %%
#Adesso cerchiamo i valori duplicati
df1.duplicated().sum()
# Out:
# 483

# %%
#Dato che abbiamo trovato alcuni dati duplicati, adesso li leviamo 
df1=df1.drop_duplicates()

# %%
#Adesso cerchiamo i valori nulli
pd.isnull(df1).sum()
# Out:
# App                  0
# Category             1
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               1
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
#Adesso assegnamo il valore '0' ai valori nulli
df1=df1.fillna(0)
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                    0
#
# ...

# %% [markdown]
# Ho scelto di assegnare lo '0' perchè vedo che molti dati fanno parte del 'Rating', quindi prendo in considerazione che abbiano valori nulli perchè sono APP sconosciute.
# Successivamente andrò aa approfondirle da sole

# %% [markdown]
# Adesso facciamo l'analisi dei dati, partiamo con gli outliers

# %%
media = df1['Rating'].mean()
soglia_outlier = df1['Rating'].std()
outlier_df_sup = df1[df1['Rating'] > media + soglia_outlier]
outlier_df_inf = df1[df1['Rating'] < media - soglia_outlier]

# %%
#Adesso iniziamo l'analisi, per prima cosa cerchiamo gli outlier
#Prima proviamo con il boxplot
flierprops = dict(marker = 'o', markersize = 8, markerfacecolor = 'lightgrey', markeredgecolor = 'Black')
boxplot = plt.boxplot(df1['Rating'], flierprops= flierprops,patch_artist=True)

for box in boxplot['boxes']:
    box.set(facecolor = 'lightblue')

plt.axhline(media,color = 'b',linestyle = '--',linewidth = 1, label = 'Media')
plt.grid(True)
plt.title('Distribuzione del rating', fontsize = 13, fontweight = '900', color = 'black')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Ci sono degli outlier Inferiori, approfondiamo la situazione

# %%
# Crea un grafico a dispersione dei dati
plt.figure(figsize=(12, 6))
plt.scatter(df1.index, df1['Rating'], label='Dati')  # Tutti i dati
plt.scatter(outlier_df_sup.index, outlier_df_sup['Rating'], color='yellow', label='Outlier', marker='x', s=100)  # Outlier evidenziati in rosso
plt.scatter(outlier_df_inf.index, outlier_df_inf['Rating'], color='red', label='Outlier', marker='x', s=100)  # Outlier evidenziati in rosso
plt.axhline(media + soglia_outlier, color='yellow', linestyle='--', label='Soglia Outlier')  # Linea per la soglia degli outlier
plt.axhline(media - soglia_outlier, color='red', linestyle='--', label='Soglia Outlier')  # Linea per la soglia degli outlier
plt.xlabel('Indice dei dati', fontsize = 10, fontweight = '900', color = 'black')
plt.ylabel('Valore', fontsize = 10, fontweight = '900', color = 'black')
plt.title('Scatter Plot con Outlier Evidenziati', fontsize = 13, fontweight = '900', color = 'black')
plt.legend(loc= (1.01,0.79))
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Vediamo come entrambi i grafici confermano che ci sono degli outlier inferiori(Dati minori della linea Rossa).
# Sono App che hanno il Rating molto basso, possiamo ipotizzare che ci sia poco interesse verso le App. Approfondiamo più tardi

# %%
#Capiamo quante App ci sono per categoria

category_counts = df1['Category'].value_counts()
category_counts
# Out:
# Category
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %% [markdown]
# Vediamo come le categorie "FAMILY", "GAME", "TOOLS" abbiano il numero più alto di applicazioni nel google play store.Vediamo se sono anche quelle con più interesse

# %%
df1.groupby('Category')['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# PRODUCTIVITY           500,000,000+10,000,000+100,000,000+10,000,000+...
# BEAUTY                 500,000+1,000,000+100,000+500,000+1,000,000+50...
# FAMILY                 50,000,000+10,000,000+100,000,000+1,000,000+5,...
# WEATHER                50,000,000+1,000,000+50,000,000+10,000+10,000,...
# PERSONALIZATION        50,000,000+1,000,000+100,000,000+5,000,000+100...
# LIBRARIES_AND_DEMO     50,000+10,000+100,000+1,000+100,000+10,000+100...
# LIFESTYLE              5,000,000+10,000,000+100,000+10,000,000+5,000,...
# BOOKS_AND_REFERENCE    100,000,000+50,000+100,000+10,000,000+100,000,...
# MAPS_AND_NAVIGATION    100,000,000+5,000,000+10,000,000+10,000,000+5,...
# EDUCATION              100,000,000+10,000,000+100,000+5,000,000+10,00...
# GAME                   100,000,000+1,000,000,000+500,000,000+10,000,0...
# ENTERTAINMENT          100,000,000+1,000,000+1,000,000+10,000,000+50,...
# EVENTS                 100,000+5,000,000+500,000+50,000+5,000,000+1,0...
# ...

# %%
df1['Reviews']= df1['Reviews'].astype(int)

# %%
df1.groupby('Category')['Reviews'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   1415536650
# COMMUNICATION           601273552
# SOCIAL                  533576829
# FAMILY                  396771969
# TOOLS                   273185044
# PHOTOGRAPHY             204297410
# VIDEO_PLAYERS           110380188
# PRODUCTIVITY            102554498
# SHOPPING                 94931162
# PERSONALIZATION          75193163
# SPORTS                   65322708
# TRAVEL_AND_LOCAL         55565160
# ENTERTAINMENT            47570716
# NEWS_AND_MAGAZINES       38245873
# HEALTH_AND_FITNESS       30845186
# MAPS_AND_NAVIGATION      30659254
# EDUCATION                23165500
# BOOKS_AND_REFERENCE      21873227
# FINANCE                  16999891
# WEATHER                  14604735
# LIFESTYLE                12820575
# BUSINESS                 12358171
# FOOD_AND_DRINK            7671576
# DATING                    5545397
# COMICS                    3383276
# HOUSE_AND_HOME            2794772
# ART_AND_DESIGN            1714440
# ...

# %%
df1['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df1['Installs']= df1['Installs'].str.replace(',','',regex=False)
df1['Installs']= df1['Installs'].str.replace('+','',regex= False)
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                    0
#
# ...

# %%
df1['Installs']= df1['Installs'].astype(int)

# %%
df1.groupby('Category')['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   31544024415
# COMMUNICATION          24152276251
# SOCIAL                 12513867902
# PRODUCTIVITY           12463091369
# TOOLS                  11452771915
# FAMILY                 10041692505
# PHOTOGRAPHY             9721247655
# TRAVEL_AND_LOCAL        6361887146
# VIDEO_PLAYERS           6222002720
# NEWS_AND_MAGAZINES      5393217760
# SHOPPING                2573348785
# ENTERTAINMENT           2455660000
# PERSONALIZATION         2074494782
# BOOKS_AND_REFERENCE     1916469576
# SPORTS                  1528574498
# HEALTH_AND_FITNESS      1361022512
# BUSINESS                 863664865
# FINANCE                  770348734
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                534823539
# EDUCATION                533952000
# WEATHER                  426100520
# FOOD_AND_DRINK           257898751
# DATING                   206536107
# HOUSE_AND_HOME           125212461
# ART_AND_DESIGN           124338100
# ...

# %%
Category_rev= df1.groupby('Category')[['Reviews','Installs']].sum().sort_values(ascending=False,by='Reviews').reset_index()
Category_rev
# Out:
#                Category     Reviews     Installs
# 0                  GAME  1415536650  31544024415
# 1         COMMUNICATION   601273552  24152276251
# 2                SOCIAL   533576829  12513867902
# 3                FAMILY   396771969  10041692505
# 4                 TOOLS   273185044  11452771915
# 5           PHOTOGRAPHY   204297410   9721247655
# 6         VIDEO_PLAYERS   110380188   6222002720
# 7          PRODUCTIVITY   102554498  12463091369
# 8              SHOPPING    94931162   2573348785
# 9       PERSONALIZATION    75193163   2074494782
# 10               SPORTS    65322708   1528574498
# 11     TRAVEL_AND_LOCAL    55565160   6361887146
# 12        ENTERTAINMENT    47570716   2455660000
# 13   NEWS_AND_MAGAZINES    38245873   5393217760
# 14   HEALTH_AND_FITNESS    30845186   1361022512
# 15  MAPS_AND_NAVIGATION    30659254    724281890
# 16            EDUCATION    23165500    533952000
# 17  BOOKS_AND_REFERENCE    21873227   1916469576
# ...

# %%
Category_rev['perc_reviews'] = round((Category_rev['Reviews']/Category_rev['Reviews'].sum())*100,3)
Category_rev.head()
# Out:
#         Category     Reviews     Installs  perc_reviews
# 0           GAME  1415536650  31544024415        33.672
# 1  COMMUNICATION   601273552  24152276251        14.303
# 2         SOCIAL   533576829  12513867902        12.692
# 3         FAMILY   396771969  10041692505         9.438
# 4          TOOLS   273185044  11452771915         6.498

# %%
sns.barplot(Category_rev[0:10],x='Category',y='perc_reviews')
plt.xticks(rotation=90)
plt.xlabel("Category", fontsize = 10, fontweight = '900', color = 'black')
plt.ylabel("perc_reviews", fontsize = 10, fontweight = '900', color = 'Black')
plt.title('Total reviews for Categorys',fontsize = 13, fontweight = '900', color = 'black')
plt.tight_layout()
plt.show()

# %% [markdown]
# Vediamo che solo la categoria "GAME" è al primo posto, "FAMILY" e "TOOLS" siano meno recensite. Adesso controlliamo le installazioni

# %%
Category_Insta = Category_rev.sort_values(by='Installs',ascending=False)
Category_Insta.drop(['perc_reviews'],axis=1,inplace=True)

# %%
Category_Insta['perc_Installs'] = round((Category_Insta['Installs']/Category_Insta['Installs'].sum())*100,3)
Category_Insta.head()
# Out:
#         Category     Reviews     Installs  perc_Installs
# 0           GAME  1415536650  31544024415         21.512
# 1  COMMUNICATION   601273552  24152276251         16.471
# 2         SOCIAL   533576829  12513867902          8.534
# 7   PRODUCTIVITY   102554498  12463091369          8.500
# 4          TOOLS   273185044  11452771915          7.811

# %%
sns.barplot(Category_Insta[0:10],x='Category',y='perc_Installs')
plt.xticks(rotation=60)
plt.title('Total Installs for Categorys', fontsize = 13, fontweight = '900', color = 'black')
plt.xlabel('Category', fontsize = 10, fontweight = '900', color = 'black')
plt.ylabel('perc_Installs', fontsize = 10, fontweight = '900', color = 'black')
plt.tight_layout()
plt.show()

# %% [markdown]
# Anche in questo caso vediamo che la categoria "GAME" è la più installata,"TOOLS" e "FAMILY" seguono come l'analisi precedente.

# %%
fig,ax = plt.subplots(1,2,figsize=(20,7))

sns.barplot(Category_Insta[0:10],x='Category',y='perc_Installs',ax=ax[0]) 
ax[0].tick_params(axis='x', rotation=60)
ax[0].set_xlabel('Category', fontsize = 10, fontweight = '900', color = 'black')
ax[0].set_ylabel('Perc_Installs', fontsize = 10, fontweight = '900')
ax[0].set_title('Total Installs for Categorys', fontsize = 13,fontweight = '900', color = 'black')

sns.barplot(Category_rev[0:10],x='Category',y='perc_reviews',ax=ax[1]) 
ax[1].tick_params(axis='x', rotation=60)
ax[1].set_xlabel('Category', fontsize = 10, fontweight = '900', color = 'black')
ax[1].set_ylabel('Perc_Reviews', fontsize = 10, fontweight = '900', color = 'black')
ax[1].set_title('Total reviews for Categorys', fontsize = 13, fontweight = '900', color = 'black')
plt.tight_layout()
plt.show()

# %% [markdown]
# Con questo grafico possiamo dedurre che la categoria "GAME" è la seconda categoria di tutto il dataset per Numero di Applicazioni(1121), la più recensità e la più installata.
# Approfondiamo perchè(da fare)

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize=(10,6))
ax1.boxplot(Category_Insta['Installs'],vert=True, patch_artist=True,boxprops = {'facecolor' : 'skyblue'})
ax1.set_ylabel('Installs', fontsize = 10, fontweight = '550', color ='black')
ax1.grid(True)
ax1.set_title('Distribuzione delle Installazioni', fontsize = 13, fontweight = '900', color = 'black')
ax2.boxplot(Category_rev['Reviews'],vert= True, patch_artist=True, boxprops= {'facecolor' : 'skyblue'})
ax2.set_ylabel('Reviews', fontsize = 10, fontweight = '550', color = 'black')
ax2.grid(True)
ax2.set_title('Distribuzione delle reviews', fontsize = 13, fontweight = '550', color = 'black')
plt.tight_layout()
plt.show()

# %%
df2
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
df2['App'].nunique()
# Out:
# 1074

# %% [markdown]
# Adesso approfondiamo la questione di tutte quelle applicazioni che avevano il "RATING" con il valore nullo, successivamente sostituito dallo '0'.

# %%
Rating_0 = df1[df1['Rating']==0]

# %%
Rating_0
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     0.0
# 113              Wrinkles and rejuvenation               BEAUTY     0.0
# 123                 Manicure - nail design               BEAUTY     0.0
# 126           Skin Care and Natural Beauty               BEAUTY     0.0
# 129    Secrets of beauty, youth and health               BEAUTY     0.0
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     0.0
# 10825                   Naruto & Boruto FR               SOCIAL     0.0
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     0.0
# 10835                             FR Forms             BUSINESS     0.0
# 10838               Parkinson Exercices FR              MEDICAL     0.0
#
#        Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# Adesso analizziamo come sono adate le App a livello di Installazioni e di Reviews per proporre delle ipotesi

# %%
Install_Rating_0 = Rating_0['Installs'].value_counts().reset_index()
Install_Rating_0
# Out:
#     Installs  count
# 0        100    407
# 1         10    316
# 2       1000    192
# 3         50    148
# 4        500    129
# 5          5     73
# 6          1     64
# 7      10000     44
# 8       5000     43
# 9     100000     19
# 10         0     15
# 11     50000     12
# 12   1000000      2
# 13    500000      1

# %%
Install_Rating_0.rename(columns={'count': 'Count'},inplace=True)

# %%
Install_Rating_0
# Out:
#     Installs  Count
# 0        100    407
# 1         10    316
# 2       1000    192
# 3         50    148
# 4        500    129
# 5          5     73
# 6          1     64
# 7      10000     44
# 8       5000     43
# 9     100000     19
# 10         0     15
# 11     50000     12
# 12   1000000      2
# 13    500000      1

# %%
Install_Rating_0.sort_values(by = 'Installs',inplace=True,ascending=False)

# %%
# Abbiamo contato e ordinato per numero di Installazioni le installazioni delle App
Install_Rating_0
# Out:
#     Installs  Count
# 12   1000000      2
# 13    500000      1
# 9     100000     19
# 11     50000     12
# 7      10000     44
# 8       5000     43
# 2       1000    192
# 4        500    129
# 0        100    407
# 3         50    148
# 1         10    316
# 5          5     73
# 6          1     64
# 10         0     15

# %%
plt.figure(figsize=(10,6))
sns.barplot(Install_Rating_0,x='Installs',y='Count', color= 'skyblue')
plt.xlabel('Numero di Installazioni per App', fontsize = 10, fontweight = '900', color = 'black')
plt.ylabel('Conteggio App', fontsize = 10, fontweight = '900', color = 'black')
plt.title('Distribuzione del numero di Installazioni per Applicazioni con Rating 0')
plt.tight_layout()
plt.show()

# %% [markdown]
# Dalla lettura della distribuzione possiamo vedere come ci siano tantissime App con Rating 0 che hanno pochissime Installazioni, per esempio vediamo come poco più di 400 app hanno 100 installazioni

# %% [markdown]
# Adesso facciamo la stessa procedura per le Reviews

# %%
Reviews_Rating_0 = Rating_0['Reviews'].value_counts().reset_index()

# %%
Reviews_Rating_0.rename(columns = {'count' : 'Count'},inplace=True)

# %%
Reviews_Rating_0.sort_values(by= 'Reviews',inplace=True,ascending=True)

# %%
Reviews_Rating_0
# Out:
#     Reviews  Count
# 0         0    593
# 1         1    205
# 2         2    131
# 3         3     94
# 4         4     63
# ..      ...    ...
# 68     1317      1
# 72     1330      1
# 77     2221      1
# 67     2536      1
# 84     3248      1
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
sns.barplot(Reviews_Rating_0[0:11], x= 'Reviews', y= 'Count')
plt.tight_layout()

# %% [markdown]
# Vediamo come poco meno di 600 applicazioni hanno 0 recensioni

# %% [markdown]
# Come ultima cosa, analizziamo il comportamento delle "Installazioni" e le "Reviews" nel tempo

# %%
Rev_timeserie_R_0 = copy.deepcopy(Rating_0)

Rev_timeserie_R_0['Last Updated'] = pd.to_datetime(Rev_timeserie_R_0['Last Updated'], format= '%B %d, %Y')
Rev_timeserie_R_0.set_index('Last Updated',inplace=True)

# %%
mediaRevMonth_R_0 = Rev_timeserie_R_0.resample('M').mean(numeric_only=True)/1000

# %%
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Plot dei dati sul primo set di assi y
ax1.plot(mediaRevMonth_R_0.index, mediaRevMonth_R_0['Reviews'], color='b', label='Recensioni')
ax1.set_xlabel('Data di Aggiornamento')
ax1.set_ylabel('Numero Totale di Recensioni', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Plot dei dati sul secondo set di assi y
ax2.plot(mediaRevMonth_R_0.index, mediaRevMonth_R_0['Installs'], color='g', label='Installazioni')
ax2.set_ylabel('Numero Totale di Installazioni', color='g')
ax2.tick_params(axis='y', labelcolor='g')

plt.title('Trend delle Recensioni Totali e delle Installazioni nel Tempo')
plt.xticks(rotation=45)

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

# Mostra il grafico
plt.show()

# %%
datacorr_R0 = Rev_timeserie_R_0['Installs'].corr(Rev_timeserie_R_0['Reviews'])
print("Correlazione tra Numero totale di installazioni e Numero totale di Installazioni:",datacorr_R0)
# Out:
# Correlazione tra Numero totale di installazioni e Numero totale di Installazioni: 0.2926175415302687

# %% [markdown]
# Possiamo dedurre quindi che le App con Rating '0' non siano conosciute dal pubblico, probabilmente per una strategia di marketing sbagliata oppure non sono state apprezzate dal segmento di mercato a cui si riferiscono

# %%
df1.describe()
# Out:
#          Rating       Reviews      Installs
# count   10358.0  1.035800e+04  1.035800e+04
# mean   3.595337  4.058654e+05  1.415639e+07
# std    1.537667  2.696651e+06  8.023580e+07
# min         0.0  0.000000e+00  0.000000e+00
# 25%         3.7  3.200000e+01  1.000000e+03
# 50%         4.2  1.678500e+03  1.000000e+05
# 75%         4.5  4.640425e+04  1.000000e+06
# max         5.0  7.815831e+07  1.000000e+09

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                    0
#
# ...

# %%
Rev_time_serie = copy.deepcopy(df1)

Rev_time_serie['Last Updated'] = pd.to_datetime(Rev_time_serie['Last Updated'], format= '%B %d, %Y')
Rev_time_serie.set_index('Last Updated',inplace=True)

# %%
mediaRevMonth = Rev_time_serie.resample('M').mean(numeric_only=True)/1000

# %%
# Analisi del trend delle recensioni totali nel tempo
plt.figure(figsize=(15, 6))
plt.plot(mediaRevMonth.index,mediaRevMonth['Reviews'])
plt.title('Trend delle Recensioni Totali nel Tempo')
plt.xlabel('Data di Aggiornamento')
plt.ylabel('Numero Totale di Recensioni')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.plot(mediaRevMonth.index,mediaRevMonth['Installs'], color = 'g')
plt.xlabel('Data di Aggiornamento')
plt.ylabel('Numero totale di Installazioni')
plt.title('Trend delle Installazioni totali nel Tempo')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(15,6))
ax2 = ax1.twinx()

ax1.plot(mediaRevMonth.index,mediaRevMonth['Reviews'], color = 'b', label = 'Recensioni')
ax1.set_xlabel('Data di Aggiornamento')
ax1.set_ylabel('Numero totale di Recensioni')
ax1.tick_params(axis='y', labelcolor = 'b')

ax2.plot(mediaRevMonth.index,mediaRevMonth['Installs'], color = 'g', label = 'Installazini')
ax2.set_ylabel('Numero totale di Installazioni')
ax2.tick_params(axis='y', labelcolor = 'g')

lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %% [markdown]
# Considerazioni: Abbiamo visto che nel 2011 non ci siano state molte installazioni e recensioni, considerando che stavano uscendo i primi smatphone e l'utenza era molto ristretta. Con il progresso tecnologico e l'avvento di nuove tecnologie è stato possibile allargare il bacino di utenza dato che sempre più persone usavano lo smartphone quotidianamente; Infatti il grafico conferma come con il passare del tempo, ci siano sempre più installazioni e recensioni.

# %%
df1F = copy.deepcopy(df1)
df1F
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                    0
#
# ...

# %%
df1F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          10358 non-null  Float64
#  3   Reviews         10358 non-null  int64
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  int64
#  6   Type            10358 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10358 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10358 non-null  object
#  12  Android Ver     10358 non-null  object
# dtypes: Float64(1), int64(2), object(10)
# memory usage: 1.1+ MB

# %%
df1F['Reviews']= df1F['Reviews'].astype(float)
df1F['Rating'] = df1F['Rating'].astype(float)

# %%
sns.scatterplot(x='Rating', y='Reviews',data=df1F)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='Rating',y='Reviews', data = df1F)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='Installs',y='Reviews', data=df1)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Vediamo che non sembrano esserci grosse correlazioni tra i vari dati, tranne che per l'ultimo grafico. Andiamo a vedere se è vero costruendo una HeatMap

# %%
df_corr = df1[['Rating', 'Installs', 'Reviews']].corr()

# %%
sns.heatmap(df_corr, annot=True, cmap='coolwarm', linewidths= 0.5)
plt.show()

# %% [markdown]
# Vediamo come l'ipotesi precendete sia confermata. esiste una relazione abbastanza forte tra il numero di installazioni e il nuemro di recensioni che riceve un'App.
# Approfondiamo la correlazione

# %%
from sklearn import datasets,linear_model,model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
Reviews_test = copy.deepcopy(df1F['Reviews'])
Reviews_test
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# 10841        19.0
# Name: Reviews, Length: 10358, dtype: float64

# %%
Installs_test = copy.deepcopy(df1F['Installs'])
Installs_test
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# 10841        1000
# Name: Installs, Length: 10358, dtype: int64

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(Installs_test,Reviews_test, test_size=0.33)

# %%
X_train = X_train.values.reshape(-1,1)

# %%
X_test = X_test.values.reshape(-1,1)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter( X_test,y_test, color = 'Blue')
plt.plot(X_test ,y_pred ,color='skyblue' ) #training line
plt.grid(True, linewidth = 0.3)

# %%
score = model.score(X_train,y_train)
print('Model determination:',score)
# Out:
# Model determination: 0.3473698965611709

# %% [markdown]
# Decidi se lasciare quest'analisi e aggiungere le altre oppure fare solo quella giusta (installs, reviews)

# %%
from sklearn.cluster import KMeans

# %%
dfcluster = copy.deepcopy(df1)

# %%
kmeans = KMeans(n_clusters= 5)
dfcluster['cluster'] = kmeans.fit_predict(dfcluster[['Reviews','Installs']])

# %%
sns.scatterplot(x= 'Rating',y='Installs', data=dfcluster,hue='cluster',palette = 'viridis')
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
dfcluster['Category'].nunique()
# Out:
# 34

# %%
dfprova = copy.deepcopy(df1)

# %%
dfprova.groupby('Category')['Rating'].mean().sort_values(ascending=True)
# Out:
# Category
# 0                           1.9
# BUSINESS               2.594145
# MEDICAL                3.095833
# EVENTS                  3.11875
# LIBRARIES_AND_DEMO     3.195294
# DATING                 3.221939
# BOOKS_AND_REFERENCE    3.345652
# NEWS_AND_MAGAZINES     3.346591
# LIFESTYLE               3.34933
# BEAUTY                 3.390566
# SPORTS                 3.442735
# PRODUCTIVITY           3.448157
# PERSONALIZATION        3.462629
# COMMUNICATION           3.48224
# TOOLS                  3.524081
# HOUSE_AND_HOME             3.54
# TRAVEL_AND_LOCAL        3.54135
# FOOD_AND_DRINK         3.559677
# PARENTING              3.583333
# AUTO_AND_VEHICLES      3.598824
# FINANCE                3.634444
# HEALTH_AND_FITNESS     3.648693
# MAPS_AND_NAVIGATION    3.667153
# FAMILY                 3.705816
# SOCIAL                 3.707857
# VIDEO_PLAYERS          3.715429
# SHOPPING               3.833929
# WEATHER                3.881707
# PHOTOGRAPHY            3.949068
# ...

# %%
dfprova.groupby('Category')['Rating'].median().sort_values(ascending=True)
# Out:
# Category
# 0                       1.9
# BUSINESS                3.7
# DATING                  4.0
# TOOLS                   4.1
# BEAUTY                  4.1
# NEWS_AND_MAGAZINES      4.1
# MEDICAL                 4.1
# LIFESTYLE               4.1
# LIBRARIES_AND_DEMO      4.1
# HOUSE_AND_HOME          4.1
# TRAVEL_AND_LOCAL        4.2
# SPORTS                  4.2
# SOCIAL                  4.2
# PRODUCTIVITY            4.2
# MAPS_AND_NAVIGATION     4.2
# VIDEO_PLAYERS           4.2
# WEATHER                 4.2
# FOOD_AND_DRINK          4.2
# FINANCE                 4.2
# FAMILY                  4.2
# ENTERTAINMENT           4.2
# AUTO_AND_VEHICLES       4.2
# COMMUNICATION           4.2
# EVENTS                 4.25
# BOOKS_AND_REFERENCE     4.3
# SHOPPING                4.3
# PHOTOGRAPHY             4.3
# PERSONALIZATION         4.3
# GAME                    4.3
# COMICS                 4.35
# PARENTING              4.35
# EDUCATION               4.4
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10841
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          10358 non-null  Float64
#  3   Reviews         10358 non-null  int64
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  int64
#  6   Type            10358 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10358 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10358 non-null  object
#  12  Android Ver     10358 non-null  object
# dtypes: Float64(1), int64(2), object(10)
# memory usage: 1.1+ MB

# %%
sns.catplot(data=df1F,x= 'Rating', y='Installs', kind= 'swarm')
