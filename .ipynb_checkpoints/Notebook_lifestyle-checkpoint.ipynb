# %%
#importo le librerie necessarie per l'analsi
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#importo i file csv

df11 = pd.read_csv('/Users/francescomangini/Desktop/Python/Vs studio code/Notebook /archive/googleplaystore.csv')
df2 = pd.read_csv('/Users/francescomangini/Desktop/Python/Vs studio code/Notebook /archive/googleplaystore_user_reviews.csv')
df1 = pd.read_csv('/Users/francescomangini/Desktop/Python/Vs studio code/Notebook /archive/googleplaystore.csv')

# %%
#inidio l'esploradione del primo dataset 
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Side', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df1.shape

#per il momento sappiamo che ci sono 10841 righe e 13 colonne
# Out:
# (10841, 13)

# %%
#visualiddo le prime 5 righe del DF
df1.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Side     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Andiamo più a fondo, cerchiamo di capire quali sono le variabili delle colonne, le intestadioni di colonna e quanto è grande il DF
df1.info()

''' 
Possiamo notare come in alcune colonne, il numero di Valori non-null sia più basso del numero totale di righe;
perciò possiamo dedurre che ci sono dei valori nulli, più avanti analidderemo nel dettaglio questo punto.
'''

# %%
df1.index

# %%
df1.side

# %%
df1.dtypes.value_counts()
#Possiamo dire con certedda che abbiamo 12 colonne con variabile "object" e 1 colonns con variabile "float64"

# %%
'''
Adesso faccio una rapida esploradione statistica del DF
(mi aspetto solo una colonna di risultato dato che ho solo una colonna con variabili numeriche)
''' 
'''Notiamo un'anomalia:
Vediamo come il rating,solitamente sia in un intervallo che va da 0 a 5,in questo caso  abbiamo 19 ceh è letteralmente fuori intervallo.
Andiamo ad approfondire la questione'''


df1.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#cerchaimo i valori che hanno 'Rating' > 5
df1[df1['Rating'] > 5.0]

#vediamo che i valori sembrano scalati di un posto verso sx
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Side Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Controlliamo con le altre righe
df1.head(5)
#Effettivamente notiamo che i dati della riga 10472 sono scalati
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Side     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#Risolviamo questa anomalia scrivendo un piccolo codice
'''In questo caso trovo utile isolare la riga per lavorarci senda intoccare il DF principale,
quindi per prima cosa '''
#df1.insert(13,'#', range(1,1 + len(df1)))

# %%
a= pd.DataFrame(df1.iloc[10472])
a= a.transpose()
cols = list(a.columns)
a = a[ cols[1:13]]
a = a.shift(periods=1,axis='columns')
a
# Out:
#       Category Rating Reviews  Side Installs  Type Price Content Rating  \
# 10472     None    1.9    19.0  3.0M   1,000+  Free     0       Everyone
#
#       Genres       Last Updated Current Ver Android Ver
# 10472    NaN  February 11, 2018      1.0.19  4.0 and up

# %%
a['App'] =  'Life Made WI-Fi Touchscreen Photo Frame'
cols = list(a.columns)
a = a[[cols[12]]+cols[0:11]]
a
# Out:
#                                            App Category Rating Reviews  Side  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame     None    1.9    19.0  3.0M
#
#       Installs  Type Price Content Rating Genres       Last Updated  \
# 10472   1,000+  Free     0       Everyone    NaN  February 11, 2018
#
#       Current Ver
# 10472      1.0.19

# %%
df1=pd.concat([df1,a],ignore_index=True)
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitd Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                 None
#
# ...

# %%
df1=df1.drop(10472,axis=0)

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10837                   Fr. Mike Schmitd Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10841            Life Made WI-Fi Touchscreen Photo Frame                 None
#
# ...

# %%
df2.columns

# %%
df2.info()

# %%
df2.index

# %%
df2.shape

# %%
df2.dtypes

# %%
df2.describe()
#ciao

# %%
df2.dtypes.value_counts()

# %%
pd.isnull(df1).sum()

# %%
pd.isnull(df2).sum()
